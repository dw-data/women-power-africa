# %% [markdown]
# Ownership of land (%)
# The proportion of women ages 15-49 or men who own land (either alone, jointly, both alone and jointly, or do not own land).
#
# ID: WB_GS_SG_OWN_LD
# https://data360.worldbank.org/en/indicator/WB_GS_SG_OWN_LD

# %%
import pandas as pd

# %%
df = pd.read_csv("WB_GS_SG_OWN_LD.csv")

# %%
# Source of African countries list: UNSD: https://unstats.un.org/unsd/methodology/m49/overview/
# Some of the names have been manually adapted to match the World Bank's encoding

africa_countries = [
    'Algeria',
    'Angola', 
    'Burundi', 
    'Benin', 
    'Burkina Faso',
    'Botswana', 
    'British Indian Ocean Territory',
    'Central African Republic', 
    "Cote d'Ivoire", 
    'Cameroon',
    'Congo, Dem. Rep.', 
    'Congo, Rep.', 
    'Comoros',
    'Cabo Verde',
    'Djibouti', 
    'Egypt, Arab Rep.',
    'Eritrea',
    'Ethiopia',
    'French Southern Territories',
    'Gabon',
    'Ghana', 
    'Guinea', 
    'Gambia, The', 
    'Guinea-Bissau',
    'Equatorial Guinea',  
    'Kenya',
    'Liberia', 
    'Libya', 
    'Lesotho',
    'Madagascar',
    'Morocco',  
    'Mali',
    'Mozambique', 
    'Mauritania',
    'Mauritius', 
    'Malawi',
    'Mayotte',
    'Namibia',
    'Niger', 
    'Nigeria', 
    'Reunion',
    'Rwanda',  
    'Saint Helena',
    'Sudan', 
    'Senegal', 
    'Sierra Leone', 
    'Somalia', 
    'South Sudan',
    'Sao Tome and Principe',
    'Eswatini',
    'Seychelles', 
    'Chad',
    'Tanzania',
    'Togo', 
    'Tunisia',
    'Uganda',
    'South Africa',
    'Western Sahara',
    'Zambia', 
    'Zimbabwe']

# %%
df_africa = df[df['REF_AREA_LABEL'].isin(africa_countries)]

# %%
df_africa.columns
# Out:
# Index(['STRUCTURE', 'STRUCTURE_ID', 'ACTION', 'FREQ', 'FREQ_LABEL', 'REF_AREA',
#        'REF_AREA_LABEL', 'INDICATOR', 'INDICATOR_LABEL', 'SEX', 'SEX_LABEL',
#        'AGE', 'AGE_LABEL', 'URBANISATION', 'URBANISATION_LABEL',
#        'UNIT_MEASURE', 'UNIT_MEASURE_LABEL', 'COMP_BREAKDOWN_1',
#        'COMP_BREAKDOWN_1_LABEL', 'COMP_BREAKDOWN_2', 'COMP_BREAKDOWN_2_LABEL',
#        'COMP_BREAKDOWN_3', 'COMP_BREAKDOWN_3_LABEL', 'TIME_PERIOD',
#        'OBS_VALUE', 'DATABASE_ID', 'DATABASE_ID_LABEL', 'UNIT_MULT',
#        'UNIT_MULT_LABEL', 'UNIT_TYPE', 'UNIT_TYPE_LABEL', 'OBS_STATUS',
#        'OBS_STATUS_LABEL', 'OBS_CONF', 'OBS_CONF_LABEL'],
#       dtype='object')

# %%
df_africa[['COMP_BREAKDOWN_1',
       'COMP_BREAKDOWN_1_LABEL', 'COMP_BREAKDOWN_2', 'COMP_BREAKDOWN_2_LABEL',
       'COMP_BREAKDOWN_3', 'COMP_BREAKDOWN_3_LABEL']]
# Out:
#        COMP_BREAKDOWN_1 COMP_BREAKDOWN_1_LABEL COMP_BREAKDOWN_2  \
# 4             WEALTH_Q1   Wealth Quintile: 1st           GS_YCU
# 16            WEALTH_Q1   Wealth Quintile: 1st           GS_YCU
# 18            WEALTH_Q1   Wealth Quintile: 1st           GS_YCU
# 19            WEALTH_Q1   Wealth Quintile: 1st           GS_YCU
# 33            WEALTH_Q1   Wealth Quintile: 1st           GS_YCU
# ...                 ...                    ...              ...
# 814060               _Z         Not Applicable           GS_LYP
# 814061               _Z         Not Applicable           GS_LYP
# 814077               _Z         Not Applicable           GS_LYP
# 814078               _Z         Not Applicable           GS_LYP
# 814079               _Z         Not Applicable           GS_LYP
#
#                        COMP_BREAKDOWN_2_LABEL COMP_BREAKDOWN_3  \
# 4       Ownership: Own both alone and jointly               _Z
# 16      Ownership: Own both alone and jointly               _Z
# ...

# %%
df_africa['COMP_BREAKDOWN_1_LABEL'].value_counts()
# Out:
# COMP_BREAKDOWN_1_LABEL
# Wealth Quintile: 1st    27648
# Wealth Quintile: 2nd    27648
# Wealth Quintile: 3rd    27648
# Wealth Quintile: 4th    27648
# Wealth Quintile: 5th    27648
# Not Applicable          27648
# Name: count, dtype: int64

# %%
df_africa_selected = df_africa[['REF_AREA_LABEL','OBS_VALUE','SEX_LABEL', 'TIME_PERIOD', 'COMP_BREAKDOWN_1_LABEL', 'COMP_BREAKDOWN_2_LABEL']].dropna()

# %%
df_africa_selected = df_africa_selected[df_africa_selected['SEX_LABEL'] == 'Female']

# %%
df_africa_selected_plot = df_africa_selected[df_africa_selected['COMP_BREAKDOWN_2_LABEL'] != 'Ownership: Do not own']

# %%
df_africa_selected_plot = df_africa_selected_plot.groupby(['REF_AREA_LABEL', 'TIME_PERIOD'])['OBS_VALUE'].mean().reset_index().dropna()

# %%
df_africa_selected_plot.to_csv("landOwners.csv", index=False)
